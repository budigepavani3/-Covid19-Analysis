# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel(r"C:\Users\Pavani\OneDrive\Attachments\Desktop\COVID19ANANALYSIS\covid.xlsx")
#pd.set_option("display.max_rows", None)
df
# Out:
#                               Country  \
# 0                         Afghanistan
# 1                             Albania
# 2                             Algeria
# 3                             Andorra
# 4                              Angola
# 5                            Anguilla
# 6                 Antigua and Barbuda
# 7                           Argentina
# 8                             Armenia
# 9                               Aruba
# 10                          Australia
# 11                            Austria
# 12                         Azerbaijan
# 13                            Bahamas
# 14                            Bahrain
# 15                         Bangladesh
# 16                           Barbados
# 17                            Belarus
# 18                            Belgium
# 19                             Belize
# 20                              Benin
# 21                            Bermuda
# 22                             Bhutan
# ...

# %%
df=df.rename(columns={"TotÂ\xa0Cases//1M pop":"toal_cases//1M","TotÂ\xa0Deaths/1M pop":'toal_deaths//1M'})
df
# Out:
#                               Country  \
# 0                         Afghanistan
# 1                             Albania
# 2                             Algeria
# 3                             Andorra
# 4                              Angola
# 5                            Anguilla
# 6                 Antigua and Barbuda
# 7                           Argentina
# 8                             Armenia
# 9                               Aruba
# 10                          Australia
# 11                            Austria
# 12                         Azerbaijan
# 13                            Bahamas
# 14                            Bahrain
# 15                         Bangladesh
# 16                           Barbados
# 17                            Belarus
# 18                            Belgium
# 19                             Belize
# 20                              Benin
# 21                            Bermuda
# 22                             Bhutan
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (225, 10)

# %%
print(df.size)
print(df.dtypes)
# Out:
# 2250
# Country                     object
# Other names                 object
# ISO 3166-1 alpha-3 CODE     object
# Population                   int64
# Continent                   object
# Total Cases                  int64
# Total Deaths                 int64
# toal_cases//1M               int64
# toal_deaths//1M              int64
# Death percentage           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  225 non-null    object
#  1   Other names              224 non-null    object
#  2   ISO 3166-1 alpha-3 CODE  225 non-null    object
#  3   Population               225 non-null    int64
#  4   Continent                225 non-null    object
#  5   Total Cases              225 non-null    int64
#  6   Total Deaths             225 non-null    int64
#  7   toal_cases//1M           225 non-null    int64
#  8   toal_deaths//1M          225 non-null    int64
#  9   Death percentage         225 non-null    float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 17.7+ KB

# %%
df.columns
df.keys()
# Out:
# Index(['Country', 'Other names', 'ISO 3166-1 alpha-3 CODE', 'Population',
#        'Continent', 'Total Cases', 'Total Deaths', 'toal_cases//1M',
#        'toal_deaths//1M', 'Death percentage'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Country                    0
# Other names                1
# ISO 3166-1 alpha-3 CODE    0
# Population                 0
# Continent                  0
# Total Cases                0
# Total Deaths               0
# toal_cases//1M             0
# toal_deaths//1M            0
# Death percentage           0
# dtype: int64

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
df['Country'].value_counts().sum()
# Out:
# np.int64(225)

# %%
df['Other names'].value_counts().sum()
# Out:
# np.int64(224)

# %%
df["ISO 3166-1 alpha-3 CODE"].value_counts().sum()
# Out:
# np.int64(225)

# %%
df['Population'].describe()
# Out:
# count    2.250000e+02
# mean     3.507321e+07
# std      1.392418e+08
# min      8.050000e+02
# 25%      5.665570e+05
# 50%      5.827911e+06
# 75%      2.190585e+07
# max      1.439324e+09
# Name: Population, dtype: float64

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa                             58
# Asia                               49
# Europe                             48
# Latin America and the Caribbean    48
# Oceania                            17
# Northern America                    5
# Name: count, dtype: int64

# %%
df['Total Cases'].describe()
# Out:
# count    2.250000e+02
# mean     2.184781e+06
# std      7.275938e+06
# min      1.000000e+00
# 25%      2.407100e+04
# 50%      1.639360e+05
# 75%      1.092547e+06
# max      8.183905e+07
# Name: Total Cases, dtype: float64

# %%
df['Total Deaths'].describe()
# Out:
# count    2.250000e+02
# mean     2.744813e+04
# std      9.689177e+04
# min      0.000000e+00
# 25%      1.890000e+02
# 50%      1.965000e+03
# 75%      1.366000e+04
# max      1.008222e+06
# Name: Total Deaths, dtype: float64

# %%
df['toal_cases//1M'].describe()
# Out:
# count       225.000000
# mean     136900.373333
# std      145060.340289
# min           9.000000
# 25%       11384.000000
# 50%       88987.000000
# 75%      223335.000000
# max      696044.000000
# Name: toal_cases//1M, dtype: float64

# %%
df['toal_deaths//1M'].describe()
# Out:
# count     225.000000
# mean     1096.715556
# std      1195.715543
# min         0.000000
# 25%       123.000000
# 50%       708.000000
# 75%      1795.000000
# max      6286.000000
# Name: toal_deaths//1M, dtype: float64

# %%
df['Death percentage'].describe()
# Out:
# count    225.000000
# mean       1.444125
# std        1.741728
# min        0.000000
# 25%        0.511291
# 50%        1.036905
# 75%        1.977017
# max       18.151787
# Name: Death percentage, dtype: float64

# %%
continuous=[ 'Population', 'Total Cases', 'Total Deaths', 'toal_cases//1M',
       'toal_deaths//1M', 'Death percentage']
print(df[continuous].describe())
print(df[continuous].skew())
# Out:
#          Population   Total Cases  Total Deaths  toal_cases//1M  \
# count  2.250000e+02  2.250000e+02  2.250000e+02      225.000000
# mean   3.507321e+07  2.184781e+06  2.744813e+04   136900.373333
# std    1.392418e+08  7.275938e+06  9.689177e+04   145060.340289
# min    8.050000e+02  1.000000e+00  0.000000e+00        9.000000
# 25%    5.665570e+05  2.407100e+04  1.890000e+02    11384.000000
# 50%    5.827911e+06  1.639360e+05  1.965000e+03    88987.000000
# 75%    2.190585e+07  1.092547e+06  1.366000e+04   223335.000000
# max    1.439324e+09  8.183905e+07  1.008222e+06   696044.000000
#
#        toal_deaths//1M  Death percentage
# count       225.000000        225.000000
# mean       1096.715556          1.444125
# std        1195.715543          1.741728
# min           0.000000          0.000000
# 25%         123.000000          0.511291
# 50%         708.000000          1.036905
# 75%        1795.000000          1.977017
# max        6286.000000         18.151787
# ...

# %%
categorical=['Country', 'Other names','Continent']
print(df[categorical].nunique())
#print(df[categorical].value_counts())
df['Continent'].value_counts()
df['Continent'].unique()
# Out:
# Country        225
# Other names    224
# Continent        6
# dtype: int64
# array(['Asia', 'Europe', 'Africa', 'Latin America and the Caribbean',
#        'Oceania', 'Northern America'], dtype=object)

# %%
sns.histplot(df["Population"],bins=10,kde=True)
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
sns.boxplot(x=df["Population"])
# Out:
# <Axes: xlabel='Population'>

# %%
sns.kdeplot(df["Population"])
# Out:
# <Axes: xlabel='Population', ylabel='Density'>

# %%
sns.histplot(df['Total Cases'],bins=10,kde=True)
# Out:
# <Axes: xlabel='Total Cases', ylabel='Count'>

# %%
sns.boxplot(x=df['Total Cases'])
# Out:
# <Axes: xlabel='Total Cases'>

# %%
sns.kdeplot(df['Total Cases'])
# Out:
# <Axes: xlabel='Total Cases', ylabel='Density'>

# %%
sns.histplot(df['Total Deaths'],bins=10,kde=True)
# Out:
# <Axes: xlabel='Total Deaths', ylabel='Count'>

# %%
sns.boxplot(x=df['Total Deaths'])
# Out:
# <Axes: xlabel='Total Deaths'>

# %%
sns.kdeplot(df['Total Deaths'])
# Out:
# <Axes: xlabel='Total Deaths', ylabel='Density'>

# %%
sns.histplot(df['toal_cases//1M'],bins=10,kde=True)
# Out:
# <Axes: xlabel='toal_cases//1M', ylabel='Count'>

# %%
sns.boxplot(x=df['toal_cases//1M'])
# Out:
# <Axes: xlabel='toal_cases//1M'>

# %%
sns.kdeplot(df['toal_cases//1M'])
# Out:
# <Axes: xlabel='toal_cases//1M', ylabel='Density'>

# %%
sns.histplot(df[ 'toal_deaths//1M'],bins=10,kde=True)
# Out:
# <Axes: xlabel='toal_deaths//1M', ylabel='Count'>

# %%
sns.boxplot(x=df['toal_deaths//1M'])
# Out:
# <Axes: xlabel='toal_deaths//1M'>

# %%
sns.kdeplot(df[ 'toal_deaths//1M'])
# Out:
# <Axes: xlabel='toal_deaths//1M', ylabel='Density'>

# %%
sns.histplot(df['Death percentage'],bins=10,kde=True)
# Out:
# <Axes: xlabel='Death percentage', ylabel='Count'>

# %%
sns.boxplot(x=df['Death percentage'])
# Out:
# <Axes: xlabel='Death percentage'>

# %%
sns.kdeplot(df['Death percentage'])
# Out:
# <Axes: xlabel='Death percentage', ylabel='Density'>

# %%
df.hist(figsize=(12,8))
plt.title("OverAll Observations")
plt.show()

# %%
plt.pie(x=df["Continent"].value_counts(),labels=df["Continent"].value_counts().index,autopct="%0.1f%%",explode=[0,0.05,0.05,0,0,0])
plt.show()

# %%
sns.countplot(x=df["Continent"])
# Out:
# <Axes: xlabel='Continent', ylabel='count'>

# %%
country_summary = df.groupby('Country').agg({
    'Population'  : 'sum',
    'Total Cases' : 'sum',
    'Total Deaths': 'sum',
}).sort_values(by='Total Cases', ascending=False)
country_summary.head(10)
# Out:
#                           Population  Total Cases  Total Deaths
# Country
# United States of America   334400597     81839052       1008222
# India                     1403754381     43029044        521388
# Brazil                     215204501     29999816        660269
# France                      65526369     25997852        142506
# Germany                     84252947     21646375        130563
# United Kingdom              68510300     21216874        165570
# Russia                     146044010     17896866        369708
# Turkey                      85927644     14894731         98157
# Italy                       60306185     14846514        159784
# S. Korea                    51346429     13874216         17235

# %%
plt.scatter(df["Total Cases"], df["Total Deaths"])
plt.xlabel("Confirmed Cases")
plt.ylabel("Deaths")
plt.title("Confirmed vs Deaths")
plt.show()

# %%
top10 = df.groupby('Country')['Total Cases'].sum().sort_values(ascending=False).head(10)
top10.plot(kind='bar', figsize=(10,5))
plt.title("Top 10 Countries by Confirmed Cases")
plt.ylabel("Cases")
plt.show()

# %%
plt.bar(df["Continent"],df['Death percentage'],width=0.5,label=df['Continent'])
plt.show()

# %%
# Fill missing numerical values with mean
num_cols = df.select_dtypes(include=np.number).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].mean())

# Fill categorical missing values
cat_cols = df.select_dtypes(include='object').columns
df[cat_cols] = df[cat_cols].fillna("Unknown")

# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
corr = df[num_cols].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
